# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("MDS-UPDRS_Part_III-Group-A.csv")

# %%
# https://blackfynn-ppmi2-curation.readthedocs-hosted.com/en/stable-documentation-branch/documentation_files/motor_assessments/tables/NUPDRS3.html

# Explanation of the dataset

# %%
df
# Out:
#        Unnamed: 0      REC_ID   PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT  \
# 0           17595   671077401   57869      V04     NUPDRS3  12/2017       1.0
# 1           21551  IANT214603  111429       BL  NUPDRDOSE3  11/2022       0.0
# 2           23302  IANT310558  182340       BL  NUPDRDOSE3  02/2023       0.0
# 3           20789  IAON164829  101018      V02  NUPDRDOSE3  11/2021       1.0
# 4           16024  IANT163527   52587      V12  NUPDRDOSE3  04/2021       0.0
# ...           ...         ...     ...      ...         ...      ...       ...
# 11959       13792   608662801   41967      V04     NUPDRS3  12/2016       1.0
# 11960       21263  IANT275548  102366      V05  NUPDRDOSE3  06/2023       0.0
# 11961        1171   741604401    3112      V15     NUPDRS3  05/2019       0.0
# 11962       18334  IANT164157   59733      R08  NUPDRDOSE3  06/2021       0.0
# 11963        8926   468805101    3916      V05     NUPDRS3  10/2014       1.0
#
# ...

# %%
df.shape
# Out:
# (11964, 63)

# %%
df.describe()
# Out:
#          Unnamed: 0          PATNO      PDTRTMNT      HRPOSTMED     HRDBSON  \
# count  11964.000000   11964.000000  10798.000000    4974.000000  144.000000
# mean   12010.606403   43012.426446      0.507409      43.310980    6.070952
# std     6889.205297   50785.199977      0.499968    2520.442216    5.527524
# min        0.000000    3000.000000      0.000000   -8760.500000  -10.766700
# 25%     6083.750000    3569.000000      0.000000       1.333300    1.291675
# 50%    12031.500000   40614.000000      1.000000       3.000000    3.541650
# 75%    17915.750000   58653.000000      1.000000      12.000000   11.000000
# max    23930.000000  293714.000000      1.000000  175321.383300   15.400000
#
#         HRDBSOFF       PDMEDYN         DBSYN   ONOFFORDER     OFFEXAM  ...  \
# count  50.000000  10285.000000  11451.000000  1223.000000  846.000000  ...
# mean    0.560676      0.528828      0.036591     1.284546    0.591017  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11964 entries, 0 to 11963
# Data columns (total 63 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   11964 non-null  int64
#  1   REC_ID       11964 non-null  object
#  2   PATNO        11964 non-null  int64
#  3   EVENT_ID     11964 non-null  object
#  4   PAG_NAME     11964 non-null  object
#  5   INFODT       11964 non-null  object
#  6   PDTRTMNT     10798 non-null  float64
#  7   PDSTATE      5499 non-null   object
#  8   HRPOSTMED    4974 non-null   float64
#  9   HRDBSON      144 non-null    float64
#  10  HRDBSOFF     50 non-null     float64
#  11  PDMEDYN      10285 non-null  float64
#  12  DBSYN        11451 non-null  float64
#  13  ONOFFORDER   1223 non-null   float64
#  14  OFFEXAM      846 non-null    float64
#  15  OFFNORSN     344 non-null    float64
#  16  DBSOFFTM     56 non-null     object
#  17  ONEXAM       876 non-null    float64
# ...

# %%
null_values = df.isna().sum()/len(df)*100
null_values.sort_values(ascending = False)
# Out:
# HRDBSOFF       99.582080
# ONNORSN        99.557004
# DBSOFFTM       99.531929
# HRDBSON        98.796389
# DBSONTM        98.737880
#                  ...
# LAST_UPDATE     0.000000
# PAG_NAME        0.000000
# INFODT          0.000000
# ORIG_ENTRY      0.000000
# Unnamed: 0      0.000000
# Length: 63, dtype: float64

# %%
i = 0
for col in df:
    column_names = df.keys().values.tolist()
    print(column_names[i],":",df[col].isna().sum())
    i=i+1
# Out:
# Unnamed: 0 : 0
# REC_ID : 0
# PATNO : 0
# EVENT_ID : 0
# PAG_NAME : 0
# INFODT : 0
# PDTRTMNT : 1166
# PDSTATE : 6465
# HRPOSTMED : 6990
# HRDBSON : 11820
# HRDBSOFF : 11914
# PDMEDYN : 1679
# DBSYN : 513
# ONOFFORDER : 10741
# OFFEXAM : 11118
# OFFNORSN : 11620
# DBSOFFTM : 11908
# ONEXAM : 11088
# ONNORSN : 11911
# DBSONTM : 11813
# PDMEDDT : 6933
# PDMEDTM : 6940
# EXAMDT : 400
# EXAMTM : 2214
# NP3SPCH : 398
# NP3FACXP : 398
# NP3RIGN : 399
# NP3RIGRU : 399
# NP3RIGLU : 399
# NP3RIGRL : 399
# NP3RIGLL : 400
# NP3FTAPR : 399
# NP3FTAPL : 402
# NP3HMOVR : 399
# NP3HMOVL : 403
# NP3PRSPR : 399
# NP3PRSPL : 401
# NP3TTAPR : 409
# NP3TTAPL : 409
# NP3LGAGR : 399
# NP3LGAGL : 400
# NP3RISNG : 400
# NP3GAIT : 400
# NP3FRZGT : 403
# NP3PSTBL : 414
# NP3POSTR : 399
# NP3BRADY : 399
# NP3PTRMR : 399
# NP3PTRML : 400
# NP3KTRMR : 400
# NP3KTRML : 399
# NP3RTARU : 399
# NP3RTALU : 399
# NP3RTARL : 399
# NP3RTALL : 399
# NP3RTALJ : 400
# NP3RTCON : 401
# NP3TOT : 1621
# DYSKPRES : 404
# ...

# %%
i = 0
for col in df:
    column_names = df.keys().values.tolist()
    print(column_names[i],":",df[col].nunique())
    i=i+1
# Out:
# Unnamed: 0 : 11964
# REC_ID : 11964
# PATNO : 2561
# EVENT_ID : 39
# PAG_NAME : 5
# INFODT : 157
# PDTRTMNT : 2
# PDSTATE : 2
# HRPOSTMED : 866
# HRDBSON : 111
# HRDBSOFF : 24
# PDMEDYN : 2
# DBSYN : 2
# ONOFFORDER : 2
# OFFEXAM : 2
# OFFNORSN : 7
# DBSOFFTM : 35
# ONEXAM : 2
# ONNORSN : 4
# DBSONTM : 59
# PDMEDDT : 147
# PDMEDTM : 370
# EXAMDT : 157
# EXAMTM : 506
# NP3SPCH : 6
# NP3FACXP : 6
# NP3RIGN : 6
# NP3RIGRU : 6
# NP3RIGLU : 6
# NP3RIGRL : 6
# NP3RIGLL : 6
# NP3FTAPR : 6
# NP3FTAPL : 6
# NP3HMOVR : 6
# NP3HMOVL : 6
# NP3PRSPR : 6
# NP3PRSPL : 6
# NP3TTAPR : 6
# NP3TTAPL : 6
# NP3LGAGR : 6
# NP3LGAGL : 6
# NP3RISNG : 6
# NP3GAIT : 6
# NP3FRZGT : 6
# NP3PSTBL : 6
# NP3POSTR : 6
# NP3BRADY : 6
# NP3PTRMR : 6
# NP3PTRML : 6
# NP3KTRMR : 5
# NP3KTRML : 6
# NP3RTARU : 6
# NP3RTALU : 6
# NP3RTARL : 6
# NP3RTALL : 6
# NP3RTALJ : 5
# NP3RTCON : 6
# NP3TOT : 81
# DYSKPRES : 2
# DYSKIRAT : 2
# NHY : 7
# ORIG_ENTRY : 159
# LAST_UPDATE : 5856

# %%
sns.boxplot(data= df.loc[:,["HRDBSOFF","HRDBSON"]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data= df.loc[:,["HRDBSON"]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data= df.loc[:,["HRPOSTMED"]])#Outlier Noted
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data= df.loc[:,["NP3SPCH","NP3FACXP","NP3RIGN","NP3KTRMR"]]) # Many more can be added
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data= df.loc[:,["NHY"]])
# Out:
# <AxesSubplot:>

# %%
grouped = df.groupby(["PATNO","PDSTATE"])

# %%
df["PDSTATE"].isna().sum()
# Out:
# 6465

# %%
df_PDSTATE_ON = pd.DataFrame()

# %%
df["PDSTATE"].value_counts()
# Out:
# ON     3258
# OFF    2241
# Name: PDSTATE, dtype: int64

# %%
df_PDSTATE_ON = df[df["PDSTATE"] == "ON"]

# %%
df_PDSTATE_ON["NP3TTAPR"].value_counts()
# Out:
# 1.0      1229
# 0.0      1007
# 2.0       691
# 3.0       205
# 101.0      46
# 4.0        22
# Name: NP3TTAPR, dtype: int64

# %%
df['PAG_NAME'].unique()
# Out:
# array(['NUPDRS3', 'NUPDRDOSE3', 'NUPDRS3A', 'NUPDR3OF', 'NUPDR3ON'],
#       dtype=object)

# %%
 # PDSTATE, NUPDR3OF, NUPDR3ON

# %%
df.loc[df['PDTRTMNT'] == 0]
# Out:
#        Unnamed: 0      REC_ID   PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT  \
# 1           21551  IANT214603  111429       BL  NUPDRDOSE3  11/2022       0.0
# 2           23302  IANT310558  182340       BL  NUPDRDOSE3  02/2023       0.0
# 4           16024  IANT163527   52587      V12  NUPDRDOSE3  04/2021       0.0
# 6           17303  IANT339104   56779      R13  NUPDRDOSE3  09/2023       0.0
# 11          19439   706863201   71394      V02     NUPDRS3  09/2018       0.0
# ...           ...         ...     ...      ...         ...      ...       ...
# 11955        4403   395407601    3426      V05     NUPDRS3  04/2013       0.0
# 11958       18729   591392401   60073      V06     NUPDRS3  09/2016       0.0
# 11960       21263  IANT275548  102366      V05  NUPDRDOSE3  06/2023       0.0
# 11961        1171   741604401    3112      V15     NUPDRS3  05/2019       0.0
# 11962       18334  IANT164157   59733      R08  NUPDRDOSE3  06/2021       0.0
#
# ...

# %%
df.loc[df['PDSTATE'] == "ON", 'PDMEDYN'].value_counts()
# Out:
# 1.0    3215
# 0.0      29
# Name: PDMEDYN, dtype: int64

# %% [markdown]
# ## ● REC_ID: Uniquely identifies the individual row on the table
# ## ● PATNO: The unique identifier of the participant
# ## ● EVENT_ID and INFODT: Capture longitudinal information about the data
# ## ● PAG_NAME: Takes the value UPSITCLINIC for tests performed under PPMI Clinical, or
# ##    UPSITPRO for tests performed under PPMI Remote (see also section 13)
# ## ● ORIG_ENTRY: The date the record was added to the PPMI database
# ## ● LAST_UPDATE: The date the record was last updated (will often be the same as
# ##    ORIG_ENTRY)

# %%
df[df["PATNO"] == 3400]
# Out:
#        Unnamed: 0      REC_ID  PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT  \
# 1690         3929  IAON295092   3400      V20  NUPDRDOSE3  07/2023       1.0
# 3166         3901   303915601   3400      V04    NUPDRS3A  07/2011       0.0
# 4025         3916   651979301   3400      V14     NUPDRS3  09/2017       1.0
# 4496         3905   377826701   3400      V07     NUPDRS3  12/2012       1.0
# 4508         3903   354451901   3400      V06    NUPDRS3A  07/2012       1.0
# 4736         3917   651979701   3400      V14    NUPDRS3A  09/2017       1.0
# 5389         3920   753134301   3400      V16    NUPDR3ON  08/2019       1.0
# 6090         3926  IAON162099   3400      V19  NUPDRDOSE3  07/2022       1.0
# 6552         3912   529097201   3400      V12    NUPDRS3A  07/2015       1.0
# 6601         3924  IAON162097   3400      V18  NUPDRDOSE3  10/2021       1.0
# 6913         3897  IAON237383   3400      R19  NUPDRDOSE3  03/2023       1.0
# ...

# %%
df_sorted = df.sort_values('PATNO')

# %%
df_sorted
# Out:
#        Unnamed: 0      REC_ID   PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT  \
# 965             6   675890201    3000      V14     NUPDRS3  02/2018       NaN
# 6117            0   272451901    3000       BL     NUPDRS3  02/2011       NaN
# 9823            7   736290801    3000      V15     NUPDRS3  03/2019       0.0
# 5829            5   563731101    3000      V12     NUPDRS3  04/2016       NaN
# 4847           17   413438401    3001      V07     NUPDRS3  09/2013       1.0
# ...           ...         ...     ...      ...         ...      ...       ...
# 8054        23920  IANT353910  292880       BL  NUPDRDOSE3  10/2023       0.0
# 9396        23923  IANT351967  292904       BL  NUPDRDOSE3  10/2023       0.0
# 9790        23925  IANT346025  292962       BL  NUPDRDOSE3  10/2023       0.0
# 2243        23928  IANT348790  293033       BL  NUPDRDOSE3  10/2023       0.0
# 10748       23930  IANT359073  293714       BL  NUPDRDOSE3  11/2023       0.0
#
# ...

# %%
df_sorted[['month','year']] = df_sorted['ORIG_ENTRY'].str.split('/', expand=True)

# %%
df_sorted = df_sorted.sort_values(['PATNO','year'])

# %%
df_sorted["PATNO"].value_counts()
# Out:
# 3420      22
# 4101      22
# 3400      22
# 4096      21
# 3407      21
#           ..
# 4075       1
# 198626     1
# 198618     1
# 167377     1
# 116259     1
# Name: PATNO, Length: 2561, dtype: int64

# %%
df_sorted[df_sorted["PATNO"] == 3435]
# Out:
#        Unnamed: 0      REC_ID  PATNO EVENT_ID    PAG_NAME   INFODT  PDTRTMNT  \
# 23           4587   318475901   3435       BL     NUPDRS3  10/2011       0.0
# 7921         4596   369436501   3435      V04     NUPDRS3  10/2012       0.0
# 7105         4595   356250101   3435      V03     NUPDRS3  07/2012       0.0
# 2860         4593   329429501   3435      V01     NUPDRS3  01/2012       0.0
# 4487         4597   395402401   3435      V05     NUPDRS3  04/2013       0.0
# 6233         4600   471213601   3435      V08     NUPDRS3  10/2014       1.0
# 11315        4601   471223901   3435      V08    NUPDRS3A  10/2014       1.0
# 5758         4603   545267001   3435      V10     NUPDRS3  11/2015       1.0
# 1971         4604   545267801   3435      V10    NUPDRS3A  11/2015       1.0
# 7322         4602   520802401   3435      V09     NUPDRS3  04/2015       1.0
# 3882         4605   564587701   3435      V11     NUPDRS3  04/2016       1.0
# ...

# %%
df_s_PDSTATEON =  df_sorted[(df_sorted["PDSTATE"] == 'ON') & (df_sorted["PATNO"] == 3435)]
df_s_PDSTATEOFF =  df_sorted[(df_sorted["PDSTATE"] == 'OFF') & (df_sorted["PATNO"] == 3435)]

# %%
df_s_PDSTATEON = df_s_PDSTATEON.sort_values('year')
df_s_PDSTATEOFF = df_s_PDSTATEOFF.sort_values('year')

# %%
plt.scatter(x =df_s_PDSTATEON['year'] ,y = df_s_PDSTATEON['HRPOSTMED'])
plt.scatter(x =df_s_PDSTATEOFF['year'] ,y = df_s_PDSTATEOFF['HRPOSTMED'])
plt.xticks(fontsize=8,rotation = 30)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.scatter(x =df_s_PDSTATEON['NHY'] ,y = df_s_PDSTATEON['NP3TOT'])
plt.scatter(x =df_s_PDSTATEOFF['NHY'] ,y = df_s_PDSTATEOFF['NP3TOT'])
plt.xticks(fontsize=8,rotation = 30)
# Out:
# (array([1.875, 1.9  , 1.925, 1.95 , 1.975, 2.   , 2.025, 2.05 , 2.075,
#         2.1  , 2.125]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
